# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanda380/archivos-del-google-colab/blob/main/ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tipos de datos:
#   -int -> numeros enteros
#   -str -> cadenas de texto
#   -float -> numeros con decimales
#   -booleano -> True & False
#   -list -> es una lista para guardad cadena de texto

# %%
nombre = input('cual es tu nombre? ')
edad = int(input('cual es tu edad? '))
print(f"hola {nombre} tienes {edad} años")
# Out:
# cual es tu nombre? juan david
# cual es tu edad? 18
# hola juan david tienes 18 años

# %%
#definimos una variable
def saludar(nombre):
  print(f"Hello {nombre} Welcome to workshop of python")
saludar(nombre)
# Out:
# Hello juan david Welcome to workshop of python

# %%
def mayor_de_edad(edad):
  if edad >= 18:
    print("eres mayor de edad")
  elif edad <= 11:
    print("eres un niño")
  else:
    print("eres menor de edad")
mayor_de_edad(edad)
# Out:
# eres mayor de edad
